# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd 
import numpy as np

# %% [markdown]
# ### ● 不動産の一つの物件から情報を取得する。

# %%
base_url = "*******"
response = requests.get(base_url)
soup     = BeautifulSoup(response.content, "lxml")
items    = soup.find(class_="cassetteitem")

# %%
# スクレイピングした HTML情報出力
f = open("test.txt", "w")
f.write(str(items))
f.close()

# %%
# 各物件情報の取得
property_name     = items.find(class_="cassetteitem_content-title").get_text() if items.find(class_="cassetteitem_content-title") else None
category          = items.find(class_="cassetteitem_content-label").span.get_text() if items.find(class_="cassetteitem_content-label") else None
address           = items.find(class_="cassetteitem_detail-col1").get_text() if items.find(class_="cassetteitem_detail-col1") else None
nearest_stations  = [station.get_text() for station in items.find_all(class_="cassetteitem_detail-text")] if items.find_all(class_="cassetteitem_detail-text") else None
construction_info = items.find(class_="cassetteitem_detail-col3").find_all("div") if items.find(class_="cassetteitem_detail-col3") else None
years_since_const = construction_info[0].get_text() if construction_info and len(construction_info) > 0 else None
number_of_floors  = construction_info[1].get_text() if construction_info and len(construction_info) > 1 else None
floor_number_td   = items.select_one("tr.js-cassette_link .cassetteitem_other-col03")
floor_number      = floor_number_td.get_text(strip=True) if floor_number_td else None
rent_info         = items.select_one(".cassetteitem_other tbody .js-cassette_link")
rent_admin_fee    = " / ".join([item.get_text(strip=True) for item in rent_info.select(".cassetteitem_price--rent, .cassetteitem_price--administration")]) if rent_info else None
deposit_gratuity  = " / ".join([price.get_text(strip=True) for price in rent_info.select(".cassetteitem_price--deposit, .cassetteitem_price--gratuity")]) if rent_info else None
layout_total_area = " / ".join([detail.get_text(strip=True) for detail in rent_info.select(".cassetteitem_madori, .cassetteitem_menseki")]) if rent_info else None


# 各物件情報の表示
print("物件名称 (Property Name):", property_name)
print("カテゴリー (Category):", category)
print("住所 (Address):", address)
print("最寄り駅 (Nearest Stations):", nearest_stations)
print("築年数 (Years Since Construction):", years_since_const)
print("階建 (Number of Floors):", number_of_floors)
print("階数 (Floor Number):", floor_number)
print("賃料/管理費 (Rent/Administration Fee):", rent_admin_fee)
print("敷金/礼金 (Deposit/Key Money):", deposit_gratuity)
print("間取り/占有面積 (Layout/Total Area):", layout_total_area)
# Out:
# 物件名称 (Property Name): アーバン増渕
# カテゴリー (Category): 賃貸マンション
# 住所 (Address): 東京都品川区西品川２
# 最寄り駅 (Nearest Stations): ['ＪＲ埼京線/大崎駅 歩10分', '東急大井町線/下神明駅 歩10分', 'ＪＲ京浜東北線/大井町駅 歩20分']
# 築年数 (Years Since Construction): 築38年
# 階建 (Number of Floors): 3階建
# 階数 (Floor Number): None
# 賃料/管理費 (Rent/Administration Fee): 15万円 / 5000円
# 敷金/礼金 (Deposit/Key Money): - / -
# 間取り/占有面積 (Layout/Total Area): 1LDK / 26.6m2

# %%
# 物件画像・間取り画像・詳細URLの取得
property_image_element = items.find(class_="cassetteitem_object-item")
property_image_url = property_image_element.img["rel"] if property_image_element and property_image_element.img else None

floor_plan_image_element = items.find(class_="casssetteitem_other-thumbnail")
floor_plan_image_url = floor_plan_image_element.img["rel"] if floor_plan_image_element and floor_plan_image_element.img else None

property_link_element = items.select_one("a[href*='/chintai/jnc_']")
property_link = "*******" + property_link_element['href'] if property_link_element else None ## 不動産サイトから詳細URLリンクを読み解き作成

# 物件画像・間取り画像・詳細URLの表示
print("物件画像 URL (Property Image URL):", property_image_url)
print("間取り情報画像 URL (Floor Plan Image URL):", floor_plan_image_url)
print("物件リンク (Property Link):", property_link)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\redgr\workspace\20231127_tech0_step3_1_01\scraping\Step3_Scraping.ipynb セル 6 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/redgr/workspace/20231127_tech0_step3_1_01/scraping/Step3_Scraping.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> # 物件画像・間取り画像・詳細URLの取得
# ----> <a href='vscode-notebook-cell:/c%3A/Users/redgr/workspace/20231127_tech0_step3_1_01/scraping/Step3_Scraping.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> property_image_element = items.find(class_="cassetteitem_object-item")
#       <a href='vscode-notebook-cell:/c%3A/Users/redgr/workspace/20231127_tech0_step3_1_01/scraping/Step3_Scraping.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> property_image_url = property_image_element.img["rel"] if property_image_element and property_image_element.img else None
#       <a href='vscode-notebook-cell:/c%3A/Users/redgr/workspace/20231127_tech0_step3_1_01/scraping/Step3_Scraping.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> floor_plan_image_element = items.find(class_="casssetteitem_other-thumbnail")
#
# NameError: name 'items' is not defined

# %% [markdown]
# ### ● 不動産の複数ページから情報を取得する。

# %%
# 基本URLと最大ページ数の設定
base_url = "*******"
max_page = 5  # 最大ページ数

all_data = []

for page in range(1, max_page + 1):
    url = base_url.format(page)
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'lxml')
    items = soup.findAll("div", {"class": "cassetteitem"})


    print("page", page, "items", len(items))

    for item in items:
        base_data = {}
        base_data["名称"]     = item.find("div", {"class": "cassetteitem_content-title"}).get_text(strip=True) if item.find("div", {"class": "cassetteitem_content-title"}) else None
        base_data["カテゴリ"] = item.find("div", {"class": "cassetteitem_content-label"}).span.get_text(strip=True) if item.find("div", {"class": "cassetteitem_content-label"}) else None
        base_data["アドレス"] = item.find("li", {"class": "cassetteitem_detail-col1"}).get_text(strip=True) if item.find("li", {"class": "cassetteitem_detail-col1"}) else None
        
        # 駅のアクセス情報をまとめて取得
        base_data["アクセス"] = ", ".join([station.get_text(strip=True) for station in item.findAll("div", {"class": "cassetteitem_detail-text"})])

        construction_info = item.find("li", {"class": "cassetteitem_detail-col3"}).find_all("div") if item.find("li", {"class": "cassetteitem_detail-col3"}) else None
        base_data["築年数"] = construction_info[0].get_text(strip=True) if construction_info and len(construction_info) > 0 else None
        base_data["構造"] = construction_info[1].get_text(strip=True) if construction_info and len(construction_info) > 1 else None

        tbodys = item.find("table", {"class": "cassetteitem_other"}).findAll("tbody")

        for tbody in tbodys:
            data = base_data.copy()
            # 階数情報の正確な取得
            floor_info = tbody.find_all("td")[2].get_text(strip=True) if len(tbody.find_all("td")) > 2 else None
            data["階数"]   = floor_info
            data["家賃"]   = tbody.select_one(".cassetteitem_price--rent").get_text(strip=True) if tbody.select_one(".cassetteitem_price--rent") else None
            data["管理費"] = tbody.select_one(".cassetteitem_price--administration").get_text(strip=True) if tbody.select_one(".cassetteitem_price--administration") else None
            data["敷金"]   = tbody.select_one(".cassetteitem_price--deposit").get_text(strip=True) if tbody.select_one(".cassetteitem_price--deposit") else None
            data["礼金"]   = tbody.select_one(".cassetteitem_price--gratuity").get_text(strip=True) if tbody.select_one(".cassetteitem_price--gratuity") else None
            data["間取り"] = tbody.select_one(".cassetteitem_madori").get_text(strip=True) if tbody.select_one(".cassetteitem_madori") else None
            data["面積"]   = tbody.select_one(".cassetteitem_menseki").get_text(strip=True) if tbody.select_one(".cassetteitem_menseki") else None

            # 物件画像・間取り画像・詳細URLの取得を最後に行う
            property_image_element = item.find(class_="cassetteitem_object-item")
            data["物件画像URL"] = property_image_element.img["rel"] if property_image_element and property_image_element.img else None

            floor_plan_image_element = item.find(class_="casssetteitem_other-thumbnail")
            data["間取画像URL"] = floor_plan_image_element.img["rel"] if floor_plan_image_element and floor_plan_image_element.img else None

            property_link_element = item.select_one("a[href*='/chintai/jnc_']")
            data["物件詳細URL"] = "******" +property_link_element['href'] if property_link_element else None ## 不動産サイトから詳細URLリンクを読み解き作成

            all_data.append(data)
# Out:
# page 1 items 30
# page 2 items 30
# page 3 items 30
# page 4 items 30
# page 5 items 30

# %%
df = pd.DataFrame(all_data)
df = df.drop_duplicates() # 重複データの削除
df.head(2)
# Out:
#                    名称    カテゴリ        アドレス                アクセス   築年数   構造  階数  \
# 0  都営新宿線 篠崎駅 3階建 築13年  賃貸アパート  東京都江戸川区鹿骨６  都営新宿線/篠崎駅 歩29分, ,   築13年  3階建  2階
# 1  都営新宿線 篠崎駅 3階建 築13年  賃貸アパート  東京都江戸川区鹿骨６  都営新宿線/篠崎駅 歩29分, ,   築13年  3階建  3階
#
#       家賃    管理費 敷金 礼金    間取り      面積  \
# 0  3.9万円  1000円  -  -  ワンルーム    12m2
# 1  3.9万円  2000円  -  -  ワンルーム  11.6m2
#
#                                              物件画像URL  \
# 0  https://img01.suumo.com/front/gazo/fr/bukken/9...
# 1  https://img01.suumo.com/front/gazo/fr/bukken/9...
#
#                                              間取画像URL  \
# 0  /edit/assets/suumo/img/mycondition_now_printin...
# 1  /edit/assets/suumo/img/mycondition_now_printin...
#
#                                              物件詳細URL
# 0  https://suumo.jp/chintai/jnc_000049422776/?bc=...
# 1  https://suumo.jp/chintai/jnc_000049422776/?bc=...

# %% [markdown]
# ### ● Googleスプレッドシートへの書き込み・読み込み。

# %%
# google スプレッドシート 書き込み・読み込み
import gspread
from google.oauth2 import service_account
from google.oauth2.service_account import Credentials
from gspread_dataframe import get_as_dataframe
from gspread_dataframe import set_with_dataframe

# %%
from dotenv import load_dotenv
import os

# 環境変数の読み込み
load_dotenv()

# 環境変数から認証情報を取得
SPREADSHEET_ID = os.getenv("SPREADSHEET_ID")
PRIVATE_KEY_PATH = os.getenv("PRIVATE_KEY_PATH")

# %%
PRIVATE_KEY_PATH
# Out:
# 'C:\\\\Users\\\\redgr\\\\workspace\\\\key\\\\grspread_key.json'

# %%
# googleスプレッドシートの認証 jsonファイル読み込み(key値はGCPから取得)
SP_CREDENTIAL_FILE = PRIVATE_KEY_PATH

scopes = [
    'https://www.googleapis.com/auth/spreadsheets',
    'https://www.googleapis.com/auth/drive'
]

credentials = Credentials.from_service_account_file(
    SP_CREDENTIAL_FILE,
    scopes=scopes
)
gc = gspread.authorize(credentials)


SP_SHEET_KEY = SPREADSHEET_ID # d/〇〇/edit の〇〇部分
sh  = gc.open_by_key(SP_SHEET_KEY)

# %%
# 取得した不動産データの書き込み
SP_SHEET_wr     = 'tech0_90' # sheet名
worksheet_wr = sh.worksheet(SP_SHEET_wr) # シートのデータ取得
set_with_dataframe(worksheet_wr, df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\redgr\workspace\20231127_tech0_step3_1_01\Step3_Scraping.ipynb セル 16 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/redgr/workspace/20231127_tech0_step3_1_01/Step3_Scraping.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> SP_SHEET_wr     = 'tech0_90' # sheet名
#       <a href='vscode-notebook-cell:/c%3A/Users/redgr/workspace/20231127_tech0_step3_1_01/Step3_Scraping.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a> worksheet_wr = sh.worksheet(SP_SHEET_wr) # シートのデータ取得
# ----> <a href='vscode-notebook-cell:/c%3A/Users/redgr/workspace/20231127_tech0_step3_1_01/Step3_Scraping.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a> set_with_dataframe(worksheet_wr, df)
#
# NameError: name 'df' is not defined

# %%
# 不動産データの取得
SP_SHEET     = 'tech0_90' # sheet名
worksheet = sh.worksheet(SP_SHEET) # シートのデータ取得
pre_data  = worksheet.get_all_values()
col_name = pre_data[0][:]
new_df = pd.DataFrame(pre_data[1:], columns=col_name) # 一段目をカラム、以下データフレームで取得

# %%
new_df.head(2)
# Out:
#        名称    カテゴリ       アドレス                                           アクセス  \
# 0  サクラハイツ  賃貸アパート  東京都世田谷区桜１  小田急線/豪徳寺駅 歩18分, 東急世田谷線/上町駅 歩6分, 小田急線/経堂駅 歩17分
# 1  サクラハイツ  賃貸アパート  東京都世田谷区桜１  小田急線/豪徳寺駅 歩18分, 東急世田谷線/上町駅 歩6分, 小田急線/経堂駅 歩17分
#
#     築年数   構造  階数     家賃 管理費     敷金 礼金 間取り    面積  \
# 0  築48年  2階建  2階  2.9万円   -  2.9万円  -  1K  21m2
# 1  築48年  2階建  1階  3.9万円   -  3.9万円  -  1K  23m2
#
#                                              物件画像URL  \
# 0  https://img01.suumo.com/front/gazo/fr/bukken/8...
# 1  https://img01.suumo.com/front/gazo/fr/bukken/8...
#
#                                              間取画像URL  \
# 0  https://img01.suumo.com/front/gazo/fr/bukken/4...
# 1  https://img01.suumo.com/front/gazo/fr/bukken/4...
#
#                                              物件詳細URL
# 0  https://suumo.jp/chintai/jnc_000086526649/?bc=...
# 1  https://suumo.jp/chintai/jnc_000086526649/?bc=...

# %% [markdown]
# ### ● 不動産データを加工する。

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   名称       408 non-null    object
#  1   カテゴリ     408 non-null    object
#  2   アドレス     408 non-null    object
#  3   アクセス     408 non-null    object
#  4   築年数      408 non-null    object
#  5   構造       408 non-null    object
#  6   階数       408 non-null    object
#  7   家賃       408 non-null    object
#  8   管理費      408 non-null    object
#  9   敷金       408 non-null    object
#  10  礼金       408 non-null    object
#  11  間取り      408 non-null    object
#  12  面積       408 non-null    object
#  13  物件画像URL  408 non-null    object
#  14  間取画像URL  408 non-null    object
#  15  物件詳細URL  408 non-null    object
# dtypes: object(16)
# memory usage: 51.1+ KB

# %%
new_df['築年数'] = new_df["築年数"].apply( lambda x: 0 if x=='新築' else int(re.split('[築年]', x )[1]) )

# %%
def get_most_floor(x):
    if ('階建' not in x) :
        return np.nan
    elif('B' not in x) :
        list = re.findall(r'(\d+)階建',str(x))
        list = map(int, list)
        min_value = min(list)
        return min_value

new_df['構造'] = new_df['構造'].apply(get_most_floor)
print(new_df['構造'].head(5))
# Out:
# 0    2
# 1    2
# 2    2
# 3    3
# 4    3
# Name: 構造, dtype: int64

# %%
def get_floor(x):
    if ('階' not in x) :
        return np.nan
    elif('B' not in x) :
        list = re.findall(r'(\d+)階',str(x))
        # time_listを数値型に変換
        list = map(int, list)
        # time_listの最小値をmin_valueに代入
        min_value = min(list)
        return min_value
    else:
        list = re.findall(r'(\d+)階',str(x))
        # time_listを数値型に変換
        list = map(int, list)
        # time_listの最小値をmin_valueに代入
        min_value = -1*min(list)
        return min_value

new_df['階数'] = new_df['階数'].apply(get_floor)
print(new_df['階数'].head(5))
# Out:
# 0    2
# 1    1
# 2    1
# 3    2
# 4    3
# Name: 階数, dtype: int64

# %%
def change_fee(x):
    if ('万円' not in x) :
        return np.nan
    else:
        return float(x.split('万円')[0])

new_df['家賃'] = new_df['家賃'].apply(change_fee)
new_df['敷金'] = new_df['敷金'].apply(change_fee)
new_df['礼金'] = new_df['礼金'].apply(change_fee)

# %%
def change_fee2(x):
    if ('円' not in x) :
        return np.nan
    else:
        return float(x.split('円')[0])


new_df['管理費'] = new_df['管理費'].apply(change_fee2)

# %%
new_df['面積'] = new_df['面積'].apply(lambda x: float(x[:-2]))

# %%
new_df['区'] = new_df["アドレス"].apply(lambda x : x[x.find("都")+1:x.find("区")+1])

# %%
new_df['市町'] = new_df["アドレス"].apply(lambda x : x[x.find("区")+1 :-1])

# %%
def split_access(row):
    accesses = row['アクセス'].split(', ')
    results = {}

    for i, access in enumerate(accesses, start=1):
        if i > 3:
            break  # 最大3つのアクセス情報のみを考慮

        parts = access.split('/')
        if len(parts) == 2:
            line_station, walk = parts
            # ' 歩'で分割できるか確認
            if ' 歩' in walk:
                station, walk_min = walk.split(' 歩')
                # 歩数の分の数値だけを抽出
                walk_min = int(re.search(r'\d+', walk_min).group())
            else:
                station = None
                walk_min = None
        else:
            line_station = access
            station = walk_min = None

        results[f'アクセス①{i}線路名'] = line_station
        results[f'アクセス①{i}駅名'] = station
        results[f'アクセス①{i}徒歩(分)'] = walk_min

    return pd.Series(results)

# 新しい列をデータフレームに適用
new_df = new_df.join(new_df.apply(split_access, axis=1))

# %%
new_df.head(2)
# Out:
#        名称    カテゴリ       アドレス                                           アクセス  \
# 0  サクラハイツ  賃貸アパート  東京都世田谷区桜１  小田急線/豪徳寺駅 歩18分, 東急世田谷線/上町駅 歩6分, 小田急線/経堂駅 歩17分
# 1  サクラハイツ  賃貸アパート  東京都世田谷区桜１  小田急線/豪徳寺駅 歩18分, 東急世田谷線/上町駅 歩6分, 小田急線/経堂駅 歩17分
#
#    築年数  構造  階数   家賃  管理費   敷金  ...  アクセス①1駅名 アクセス①1徒歩(分)  アクセス①2線路名 アクセス①2駅名  \
# 0   48   2   2  2.9  NaN  2.9  ...      豪徳寺駅          18     東急世田谷線      上町駅
# 1   48   2   1  3.9  NaN  3.9  ...      豪徳寺駅          18     東急世田谷線      上町駅
#
#   アクセス①2徒歩(分) アクセス①3線路名 アクセス①3駅名 アクセス①3徒歩(分) latitude longitude
# 0         6.0      小田急線      経堂駅        17.0      NaN       NaN
# 1         6.0      小田急線      経堂駅        17.0      NaN       NaN
#
# [2 rows x 29 columns]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   名称           408 non-null    object
#  1   カテゴリ         408 non-null    object
#  2   アドレス         408 non-null    object
#  3   アクセス         408 non-null    object
#  4   築年数          408 non-null    int64
#  5   構造           408 non-null    int64
#  6   階数           408 non-null    int64
#  7   家賃           408 non-null    float64
#  8   管理費          332 non-null    float64
#  9   敷金           181 non-null    float64
#  10  礼金           83 non-null     float64
#  11  間取り          408 non-null    object
#  12  面積           408 non-null    float64
#  13  物件画像URL      408 non-null    object
#  14  間取画像URL      408 non-null    object
#  15  物件詳細URL      408 non-null    object
#  16  区            408 non-null    object
#  17  市町           408 non-null    object
#  18  アクセス①1線路名    408 non-null    object
#  19  アクセス①1駅名     408 non-null    object
#  20  アクセス①1徒歩(分)  408 non-null    int64
#  21  アクセス①2線路名    408 non-null    object
#  22  アクセス①2駅名     342 non-null    object
#  23  アクセス①2徒歩(分)  342 non-null    float64
#  24  アクセス①3線路名    408 non-null    object
#  25  アクセス①3駅名     318 non-null    object
#  26  アクセス①3徒歩(分)  318 non-null    float64
#  27  latitude     111 non-null    float64
#  28  longitude    111 non-null    float64
# dtypes: float64(9), int64(4), object(16)
# memory usage: 92.6+ KB

# %%
# 取得した不動産データの書き込み
SP_SHEET_wr     = 'tech0_91' # sheet名
worksheet_wr = sh.worksheet(SP_SHEET_wr) # シートのデータ取得
set_with_dataframe(worksheet_wr, new_df)

# %% [markdown]
# ### ● 緯度経度情報取得

# %%
# 不動産データの取得
SP_SHEET     = 'tech0_01' # sheet名
worksheet = sh.worksheet(SP_SHEET) # シートのデータ取得
pre_data  = worksheet.get_all_values()
col_name = pre_data[0][:]
new_df = pd.DataFrame(pre_data[1:], columns=col_name) # 一段目をカラム、以下データフレームで取得

# %%
# ジオコーダーの初期化
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="your_app_name")

current_count = 0
total_count = len(new_df['アドレス'])


# 住所から緯度と経度を取得する関数
def get_lat_lon(address):
    global current_count
    current_count += 1

    try:
        location = geolocator.geocode(address)
        print(f"{current_count}/{total_count} 件目実施中 結果: {location.latitude}, {location.longitude}")

        if location:
            return location.latitude, location.longitude
        else:
            return None, None
    except Exception as e:
        print(f"Error retrieving location for address {address}: {e}")
        return None, None

# %%
location = geolocator.geocode("東京都江戸川区篠崎町７")
print(location)

# %%
# 住所列があると仮定して、緯度経度列をデータフレームに追加
new_df['latitude'], new_df['longitude'] = zip(*new_df['アドレス'].apply(get_lat_lon))
# Out:
# Error retrieving location for address 東京都江戸川区鹿骨６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区鹿骨６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区鹿骨６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区鹿骨６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区鹿骨６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区鹿骨６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区鹿骨６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区鹿骨６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区北烏山４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西篠崎２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西篠崎２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区北小岩５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区北小岩５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西篠崎１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西篠崎１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西篠崎１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区桜上水４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区篠崎町４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区篠崎町４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区篠崎町４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区篠崎町４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区桜丘１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区桜丘１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区南葛西４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小岩１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区篠崎町６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区篠崎町６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西小岩４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西小岩４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西小岩４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区北小岩８: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区上篠崎３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区上篠崎３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区鹿骨３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区鹿骨３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区上篠崎３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区上篠崎３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西瑞江５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西瑞江５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東葛西１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東葛西１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区篠崎町６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西葛西３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西葛西３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西葛西３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西葛西３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西葛西３: 'NoneType' object has no attribute 'latitude'
# 48/11743 件目実施中 結果: 35.6431914, 139.6612099
# 49/11743 件目実施中 結果: 35.6431914, 139.6612099
# 50/11743 件目実施中 結果: 35.6431914, 139.6612099
# Error retrieving location for address 東京都江戸川区大杉４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区大杉４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区一之江４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区一之江４: 'NoneType' object has no attribute 'latitude'
# 55/11743 件目実施中 結果: 35.6431914, 139.6612099
# 56/11743 件目実施中 結果: 35.6431914, 139.6612099
# 57/11743 件目実施中 結果: 35.6431914, 139.6612099
# 58/11743 件目実施中 結果: 35.7089725, 139.8850814
# Error retrieving location for address 東京都江戸川区中葛西６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中葛西６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中葛西６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中葛西６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中葛西６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中葛西６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中葛西６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中葛西６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区祖師谷３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区桜丘３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中央３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中央３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中央３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中央３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中央３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中央３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中央３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区西品川２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区西品川２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中央３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中央３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中央３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中央３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中央３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中央３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区瑞江１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区瑞江１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区千歳台３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区喜多見４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区喜多見４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中葛西１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中葛西１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中葛西１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中葛西１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区宇奈根３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区宇奈根３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区赤堤４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区赤堤４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区赤堤４: 'NoneType' object has no attribute 'latitude'
# 98/11743 件目実施中 結果: 35.72253375, 139.79537915
# Error retrieving location for address 東京都江戸川区北小岩３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区北小岩３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区北小岩３: 'NoneType' object has no attribute 'latitude'
# 102/11743 件目実施中 結果: 34.81982965, 135.75332133086772
# 103/11743 件目実施中 結果: 34.81982965, 135.75332133086772
# Error retrieving location for address 東京都世田谷区給田２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区給田２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区給田２: 'NoneType' object has no attribute 'latitude'
# 107/11743 件目実施中 結果: 35.6634091, 139.8574192
# 108/11743 件目実施中 結果: 35.6634091, 139.8574192
# 109/11743 件目実施中 結果: 35.6634091, 139.8574192
# Error retrieving location for address 東京都江戸川区南篠崎町３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区南篠崎町３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区南篠崎町３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区南篠崎町３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区南篠崎町３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区南篠崎町３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区南篠崎町３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区南篠崎町３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区南篠崎町３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区南篠崎町３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区上馬１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区上馬１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区砧６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区砧６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区砧６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区砧６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区経堂２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区経堂２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東松本２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東松本２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区砧６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区砧６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区砧６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区船堀２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区船堀２: 'NoneType' object has no attribute 'latitude'
# 135/11743 件目実施中 結果: 35.6588473, 139.6609975
# Error retrieving location for address 東京都江戸川区南篠崎町４: 'NoneType' object has no attribute 'latitude'
# 137/11743 件目実施中 結果: 35.7305848, 139.8790107
# 138/11743 件目実施中 結果: 35.7305848, 139.8790107
# 139/11743 件目実施中 結果: 35.7305848, 139.8790107
# 140/11743 件目実施中 結果: 35.6439717, 139.6710889
# 141/11743 件目実施中 結果: 35.6439717, 139.6710889
# 142/11743 件目実施中 結果: 35.6439717, 139.6710889
# 143/11743 件目実施中 結果: 35.6439717, 139.6710889
# 144/11743 件目実施中 結果: 35.6439717, 139.6710889
# Error retrieving location for address 東京都江戸川区篠崎町４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区篠崎町４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区篠崎町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区篠崎町２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区南小岩４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区南小岩４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小岩３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小岩３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小岩３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小岩３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小岩３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小岩３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小岩３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小岩３: 'NoneType' object has no attribute 'latitude'
# 159/11743 件目実施中 結果: 35.6099682, 139.6389302
# 160/11743 件目実施中 結果: 35.6099682, 139.6389302
# 161/11743 件目実施中 結果: 35.6099682, 139.6389302
# 162/11743 件目実施中 結果: 35.6099682, 139.6389302
# 163/11743 件目実施中 結果: 35.6099682, 139.6389302
# Error retrieving location for address 東京都江戸川区西小岩３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西小岩３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小松川４: 'NoneType' object has no attribute 'latitude'
# 167/11743 件目実施中 結果: 35.6438377, 139.6691734
# 168/11743 件目実施中 結果: 35.6438377, 139.6691734
# 169/11743 件目実施中 結果: 35.6438377, 139.6691734
# 170/11743 件目実施中 結果: 35.6438377, 139.6691734
# 171/11743 件目実施中 結果: 35.7305848, 139.8790107
# 172/11743 件目実施中 結果: 35.7305848, 139.8790107
# 173/11743 件目実施中 結果: 35.7305848, 139.8790107
# 174/11743 件目実施中 結果: 35.7305848, 139.8790107
# Error retrieving location for address 東京都江戸川区江戸川３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区江戸川３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区西五反田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区西五反田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区西五反田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区西五反田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区西五反田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区西五反田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区西五反田１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区西五反田１: 'NoneType' object has no attribute 'latitude'
# 185/11743 件目実施中 結果: 35.668436850000006, 139.66936518639957
# 186/11743 件目実施中 結果: 35.668436850000006, 139.66936518639957
# Error retrieving location for address 東京都江戸川区春江町３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区八幡山３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区篠崎町７: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小松川３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小松川３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小松川３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区北葛西２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区北葛西２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区春江町２: 'NoneType' object has no attribute 'latitude'
# 196/11743 件目実施中 結果: 35.65839875, 139.6620597095456
# 197/11743 件目実施中 結果: 35.65839875, 139.6620597095456
# 198/11743 件目実施中 結果: 35.6445109, 139.6534542
# Error retrieving location for address 東京都江戸川区西葛西５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西葛西５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西葛西５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西葛西５: 'NoneType' object has no attribute 'latitude'
# 203/11743 件目実施中 結果: 35.6393519, 139.6638794
# 204/11743 件目実施中 結果: 35.6393519, 139.6638794
# 205/11743 件目実施中 結果: 35.6393519, 139.6638794
# 206/11743 件目実施中 結果: 35.6393519, 139.6638794
# 207/11743 件目実施中 結果: 35.6984235, 139.8620204
# 208/11743 件目実施中 結果: 35.6984235, 139.8620204
# 209/11743 件目実施中 結果: 35.6984235, 139.8620204
# Error retrieving location for address 東京都世田谷区代田６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区代田６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区代田６: 'NoneType' object has no attribute 'latitude'
# 213/11743 件目実施中 結果: 35.6499595, 139.6613014
# 214/11743 件目実施中 結果: 35.6499595, 139.6613014
# Error retrieving location for address 東京都品川区南品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区南品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区南品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区南品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区南品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区南品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区南品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区南品川４: 'NoneType' object has no attribute 'latitude'
# 223/11743 件目実施中 結果: 35.6278196, 139.6358003
# 224/11743 件目実施中 結果: 35.6278196, 139.6358003
# 225/11743 件目実施中 結果: 35.6278196, 139.6358003
# 226/11743 件目実施中 結果: 35.6278196, 139.6358003
# 227/11743 件目実施中 結果: 35.6278196, 139.6358003
# 228/11743 件目実施中 結果: 35.6278196, 139.6358003
# Error retrieving location for address 東京都世田谷区代田６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区南烏山４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区松原３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区松原３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区松原３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区松原３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区松原３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区松原３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区松原３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区三軒茶屋１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区三軒茶屋１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区三軒茶屋１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西小岩３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西小岩３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区上馬１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小岩６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小岩６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小岩６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小岩６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小岩６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小岩６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小岩６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小岩６: 'NoneType' object has no attribute 'latitude'
# 252/11743 件目実施中 結果: 35.6687793, 139.5994932
# 253/11743 件目実施中 結果: 35.6687793, 139.5994932
# 254/11743 件目実施中 結果: 35.6687793, 139.5994932
# Error retrieving location for address 東京都世田谷区上馬４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区上馬４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区上馬４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区上馬４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区上篠崎１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区上篠崎１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区上篠崎１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区上篠崎２: 'NoneType' object has no attribute 'latitude'
# 263/11743 件目実施中 結果: 35.7089725, 139.8850814
# Error retrieving location for address 東京都江戸川区上篠崎４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区上篠崎４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区上篠崎４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区上篠崎４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中葛西８: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区駒沢２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区駒沢２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区駒沢２: 'NoneType' object has no attribute 'latitude'
# 272/11743 件目実施中 結果: 35.73015735, 139.88616854655686
# Error retrieving location for address 東京都世田谷区駒沢２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区駒沢２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区駒沢２: 'NoneType' object has no attribute 'latitude'
# 276/11743 件目実施中 結果: 35.6648434, 139.8570671
# 277/11743 件目実施中 結果: 35.66681, 139.65281115013045
# 278/11743 件目実施中 結果: 35.601052, 139.715239
# 279/11743 件目実施中 結果: 35.601052, 139.715239
# 280/11743 件目実施中 結果: 35.73015735, 139.88616854655686
# 281/11743 件目実施中 結果: 35.704284200000004, 139.79401450818966
# 282/11743 件目実施中 結果: 35.704284200000004, 139.79401450818966
# Error retrieving location for address 東京都世田谷区赤堤４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区赤堤４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区赤堤４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区赤堤４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区赤堤４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区赤堤４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区赤堤４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東瑞江１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東瑞江１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区給田４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区給田４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区給田４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区新堀２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区新堀２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区下馬５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区上祖師谷２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区上祖師谷２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区上祖師谷２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区上祖師谷２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区上祖師谷２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区上祖師谷２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区奥沢３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区奥沢３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区奥沢３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区奥沢３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区北小岩７: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区上北沢５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区上北沢５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区南品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区南品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区南品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区南品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区南品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区南品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区南品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区駒沢１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区赤堤３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区赤堤３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区赤堤３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区赤堤３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区赤堤３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区赤堤３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区赤堤３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区赤堤３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区赤堤３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区赤堤３: 'NoneType' object has no attribute 'latitude'
# 329/11743 件目実施中 結果: 35.66681, 139.65281115013045
# 330/11743 件目実施中 結果: 35.66681, 139.65281115013045
# 331/11743 件目実施中 結果: 35.66681, 139.65281115013045
# 332/11743 件目実施中 結果: 35.66681, 139.65281115013045
# 333/11743 件目実施中 結果: 35.66681, 139.65281115013045
# 334/11743 件目実施中 結果: 35.66681, 139.65281115013045
# 335/11743 件目実施中 結果: 35.66681, 139.65281115013045
# Error retrieving location for address 東京都江戸川区平井１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区平井１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区平井１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区松江１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区松江１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区松江１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区松江１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区松江１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区松江１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区松江１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西小岩２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西小岩２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区一之江６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区春江町２: 'NoneType' object has no attribute 'latitude'
# 350/11743 件目実施中 結果: 35.7089725, 139.8850814
# Error retrieving location for address 東京都世田谷区上北沢５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区上北沢５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区上北沢５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区給田３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区根岸３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区根岸３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区駒沢１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区駒沢１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区代沢３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区代沢３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区代沢３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区上篠崎１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区上篠崎１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区上篠崎１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区上篠崎１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区南烏山４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区南烏山４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区南烏山４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小岩６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小岩６: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区松島３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区松島３: 'NoneType' object has no attribute 'latitude'
# 373/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 374/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 375/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 376/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 377/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 378/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 379/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 380/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 381/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 382/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 383/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 384/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 385/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 386/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 387/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 388/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 389/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 390/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 391/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 392/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 393/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 394/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# Error retrieving location for address 東京都江戸川区東小岩１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小岩１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小岩１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小岩１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区駒沢２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区駒沢２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区北小岩４: 'NoneType' object has no attribute 'latitude'
# 402/11743 件目実施中 結果: 35.61300715, 139.71000067379254
# 403/11743 件目実施中 結果: 35.61300715, 139.71000067379254
# 404/11743 件目実施中 結果: 35.61300715, 139.71000067379254
# 405/11743 件目実施中 結果: 35.61300715, 139.71000067379254
# Error retrieving location for address 東京都江戸川区中央２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中央２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中央２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中央２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中央２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中央２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中央２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区瑞江１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区瑞江１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区瑞江１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区鹿骨３: 'NoneType' object has no attribute 'latitude'
# 417/11743 件目実施中 結果: 35.63092, 139.599622
# 418/11743 件目実施中 結果: 35.6304141, 139.6544772
# 419/11743 件目実施中 結果: 34.81982965, 135.75332133086772
# 420/11743 件目実施中 結果: 34.81982965, 135.75332133086772
# 421/11743 件目実施中 結果: 34.81982965, 135.75332133086772
# Error retrieving location for address 東京都江戸川区松江６: 'NoneType' object has no attribute 'latitude'
# 423/11743 件目実施中 結果: 35.7305848, 139.8790107
# 424/11743 件目実施中 結果: 35.7305848, 139.8790107
# Error retrieving location for address 東京都江戸川区平井１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区平井１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区平井１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区平井１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区松江１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区松江１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区松江１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区松江１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区松江１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区松江１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区松江１: 'NoneType' object has no attribute 'latitude'
# 436/11743 件目実施中 結果: 35.626881049999994, 139.71846541812772
# 437/11743 件目実施中 結果: 35.626881049999994, 139.71846541812772
# 438/11743 件目実施中 結果: 35.626881049999994, 139.71846541812772
# 439/11743 件目実施中 結果: 35.626881049999994, 139.71846541812772
# 440/11743 件目実施中 結果: 35.626881049999994, 139.71846541812772
# 441/11743 件目実施中 結果: 35.626881049999994, 139.71846541812772
# 442/11743 件目実施中 結果: 35.626881049999994, 139.71846541812772
# 443/11743 件目実施中 結果: 35.626881049999994, 139.71846541812772
# 444/11743 件目実施中 結果: 35.626881049999994, 139.71846541812772
# 445/11743 件目実施中 結果: 35.626881049999994, 139.71846541812772
# 446/11743 件目実施中 結果: 35.626881049999994, 139.71846541812772
# 447/11743 件目実施中 結果: 35.626881049999994, 139.71846541812772
# Error retrieving location for address 東京都江戸川区西瑞江４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西瑞江４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西瑞江４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区船堀５: 'NoneType' object has no attribute 'latitude'
# 452/11743 件目実施中 結果: 35.7428481, 139.8831187
# 453/11743 件目実施中 結果: 35.7428481, 139.8831187
# Error retrieving location for address 東京都江戸川区西小岩１: 'NoneType' object has no attribute 'latitude'
# 455/11743 件目実施中 結果: 35.6634772, 139.668713
# 456/11743 件目実施中 結果: 35.6634772, 139.668713
# Error retrieving location for address 東京都世田谷区南烏山４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区南烏山４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区南烏山４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区南烏山４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区南烏山４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中央１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区桜１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区北小岩３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区北小岩３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区瑞江１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区瑞江１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小松川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東小松川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中央３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中央３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区北葛西２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区北葛西２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区北葛西２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区北葛西２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区北葛西２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区北小岩８: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区桜３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区瑞江１: 'NoneType' object has no attribute 'latitude'
# 480/11743 件目実施中 結果: 35.6342688, 139.6803781
# 481/11743 件目実施中 結果: 35.6342688, 139.6803781
# Error retrieving location for address 東京都江戸川区南篠崎町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区中葛西５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区平井３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区船橋４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区松原５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区松原５: 'NoneType' object has no attribute 'latitude'
# 488/11743 件目実施中 結果: 35.7428481, 139.8831187
# 489/11743 件目実施中 結果: 35.7428481, 139.8831187
# 490/11743 件目実施中 結果: 35.7428481, 139.8831187
# Error retrieving location for address 東京都世田谷区三軒茶屋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区三軒茶屋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区三軒茶屋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区三軒茶屋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区三軒茶屋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区三軒茶屋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区三軒茶屋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区三軒茶屋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区三軒茶屋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区三軒茶屋２: 'NoneType' object has no attribute 'latitude'
# 501/11743 件目実施中 結果: 35.72253375, 139.79537915
# 502/11743 件目実施中 結果: 35.72253375, 139.79537915
# 503/11743 件目実施中 結果: 35.72253375, 139.79537915
# 504/11743 件目実施中 結果: 35.6259582, 139.7162327
# 505/11743 件目実施中 結果: 35.6259582, 139.7162327
# 506/11743 件目実施中 結果: 35.6259582, 139.7162327
# 507/11743 件目実施中 結果: 35.6259582, 139.7162327
# 508/11743 件目実施中 結果: 35.6259582, 139.7162327
# 509/11743 件目実施中 結果: 35.6259582, 139.7162327
# 510/11743 件目実施中 結果: 35.6259582, 139.7162327
# 511/11743 件目実施中 結果: 35.6259582, 139.7162327
# 512/11743 件目実施中 結果: 35.6259582, 139.7162327
# 513/11743 件目実施中 結果: 35.6259582, 139.7162327
# Error retrieving location for address 東京都世田谷区三軒茶屋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区三軒茶屋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区三軒茶屋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区三軒茶屋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区上馬４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区北小岩２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区北小岩２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区北小岩２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区祖師谷１: 'NoneType' object has no attribute 'latitude'
# 523/11743 件目実施中 結果: 35.6439717, 139.6710889
# 524/11743 件目実施中 結果: 35.6439717, 139.6710889
# 525/11743 件目実施中 結果: 35.6439717, 139.6710889
# 526/11743 件目実施中 結果: 35.6439717, 139.6710889
# Error retrieving location for address 東京都江戸川区東小松川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西葛西８: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西葛西８: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西葛西８: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西葛西８: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区北小岩２: 'NoneType' object has no attribute 'latitude'
# 533/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 534/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 535/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 536/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 537/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 538/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 539/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 540/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 541/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# 542/11743 件目実施中 結果: 35.7297233, 139.88735534628375
# Error retrieving location for address 東京都江戸川区南篠崎町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東松本２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区竜泉１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区松原４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区松原４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区松原４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区松原４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西小岩１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区西小岩１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区西品川２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区松原４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区松原４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区松原４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区平井７: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区上北沢４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区上北沢４: 'NoneType' object has no attribute 'latitude'
# 559/11743 件目実施中 結果: 35.6593069, 139.6650026
# 560/11743 件目実施中 結果: 35.6593069, 139.6650026
# 561/11743 件目実施中 結果: 35.6593069, 139.6650026
# 562/11743 件目実施中 結果: 35.6593069, 139.6650026
# 563/11743 件目実施中 結果: 35.6593069, 139.6650026
# 564/11743 件目実施中 結果: 34.81982965, 135.75332133086772
# Error retrieving location for address 東京都江戸川区南葛西２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区南葛西２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区南葛西２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区下谷１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区下谷１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区下谷１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区下谷１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区下谷１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区宮坂２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区柳橋１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区柳橋１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区代沢３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区代沢３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区代沢３: 'NoneType' object has no attribute 'latitude'
# ...
# Error retrieving location for address 東京都台東区柳橋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区柳橋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区柳橋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区柳橋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区柳橋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区柳橋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区柳橋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区柳橋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区柳橋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区柳橋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区柳橋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区柳橋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区柳橋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区柳橋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区柳橋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区柳橋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区柳橋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区柳橋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区柳橋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区柳橋２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区新川２: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区新川２: 'NoneType' object has no attribute 'latitude'
# 11599/11743 件目実施中 結果: 35.7041208, 139.7917295
# Error retrieving location for address 東京都港区芝５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区芝５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区芝５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区芝５: 'NoneType' object has no attribute 'latitude'
# 11604/11743 件目実施中 結果: 35.65839875, 139.6620597095456
# Error retrieving location for address 東京都世田谷区代沢５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区代沢５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区代沢５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区代沢５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区代沢５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区代沢５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区代沢５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区代沢５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区代沢５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区代沢５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区八幡山１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都世田谷区八幡山１: 'NoneType' object has no attribute 'latitude'
# 11617/11743 件目実施中 結果: 35.6045276, 139.7268131
# 11618/11743 件目実施中 結果: 35.6045276, 139.7268131
# 11619/11743 件目実施中 結果: 35.6045276, 139.7268131
# 11620/11743 件目実施中 結果: 35.6045276, 139.7268131
# 11621/11743 件目実施中 結果: 35.6045276, 139.7268131
# 11622/11743 件目実施中 結果: 35.6045276, 139.7268131
# 11623/11743 件目実施中 結果: 35.6045276, 139.7268131
# 11624/11743 件目実施中 結果: 35.6045276, 139.7268131
# 11625/11743 件目実施中 結果: 35.6045276, 139.7268131
# 11626/11743 件目実施中 結果: 35.6045276, 139.7268131
# Error retrieving location for address 東京都港区六本木５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区六本木５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区六本木５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区六本木５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区六本木５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区東品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区東品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区東品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区東品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区東品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区東品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区東品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区東品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区東品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区東品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区東品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区東品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区東品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区東品川４: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=%E6%9D%B1%E4%BA%AC%E9%83%BD%E5%93%81%E5%B7%9D%E5%8C%BA%E6%9D%B1%E5%93%81%E5%B7%9D%EF%BC%94&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error retrieving location for address 東京都品川区東品川４: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=%E6%9D%B1%E4%BA%AC%E9%83%BD%E5%93%81%E5%B7%9D%E5%8C%BA%E6%9D%B1%E5%93%81%E5%B7%9D%EF%BC%94&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error retrieving location for address 東京都品川区東品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区東品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区東品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区東品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区東品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都品川区東品川４: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金台３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金台３: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=%E6%9D%B1%E4%BA%AC%E9%83%BD%E6%B8%AF%E5%8C%BA%E7%99%BD%E9%87%91%E5%8F%B0%EF%BC%93&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error retrieving location for address 東京都港区白金台３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金台３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金台３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金台３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金台３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金台３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金台３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金台３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金台３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金台３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金台３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金台３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金台３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金台３: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東葛西５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東葛西５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区日本橋堀留町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区日本橋堀留町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区日本橋堀留町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区日本橋堀留町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区日本橋堀留町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区日本橋堀留町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区日本橋堀留町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区日本橋堀留町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区日本橋堀留町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区日本橋堀留町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区日本橋堀留町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区日本橋堀留町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区日本橋堀留町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区日本橋堀留町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区日本橋堀留町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区日本橋堀留町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区日本橋堀留町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区日本橋堀留町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区日本橋堀留町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区日本橋堀留町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区日本橋堀留町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区日本橋堀留町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区日本橋堀留町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区日本橋堀留町１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都中央区日本橋堀留町１: 'NoneType' object has no attribute 'latitude'
# 11715/11743 件目実施中 結果: 35.6943762, 139.7843988
# 11716/11743 件目実施中 結果: 35.6943762, 139.7843988
# 11717/11743 件目実施中 結果: 35.6943762, 139.7843988
# 11718/11743 件目実施中 結果: 35.6943762, 139.7843988
# Error retrieving location for address 東京都台東区浅草橋５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都台東区浅草橋５: 'NoneType' object has no attribute 'latitude'
# 11721/11743 件目実施中 結果: 35.6064427, 139.7490606
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区白金１: 'NoneType' object has no attribute 'latitude'
# 11738/11743 件目実施中 結果: 35.5952045, 139.7346625
# Error retrieving location for address 東京都港区三田５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区三田５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区三田５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都港区三田５: 'NoneType' object has no attribute 'latitude'
# Error retrieving location for address 東京都江戸川区東瑞江３: 'NoneType' object has no attribute 'latitude'

# %%
# 取得した不動産データの書き込み
SP_SHEET_wr     = 'tech0_01' # sheet名
worksheet_wr = sh.worksheet(SP_SHEET_wr) # シートのデータ取得
set_with_dataframe(worksheet_wr, new_df)
